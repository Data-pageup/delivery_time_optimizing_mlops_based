# %%
# libraries

import pandas as pd

# %%
df = pd.read_csv('../data/raw/orders.csv')

# %%
df.isnull().sum()
# Out:
# ID                              0
# Delivery_person_ID              0
# Delivery_person_Age             0
# Delivery_person_Ratings         0
# Restaurant_latitude             0
# Restaurant_longitude            0
# Delivery_location_latitude      0
# Delivery_location_longitude     0
# Order_Date                      0
# Time_Orderd                     0
# Time_Order_picked               0
# Weatherconditions               0
# Road_traffic_density            0
# Vehicle_condition               0
# Type_of_order                   0
# Type_of_vehicle                 0
# multiple_deliveries             0
# Festival                       18
# City                           92
# Time_taken(min)                 0
# delivery_time_mins              0
# weather_clean                   0
# is_late                         0
# distance_km                     0
# dtype: int64

# %% [markdown]
# # handling missing values

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weatherconditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken(min)',
#        'delivery_time_mins', 'weather_clean', 'is_late', 'distance_km'],
#       dtype='object')

# %% [markdown]
# # removing unwanted columns

# %%
# dropping columns 

df.drop(columns= [ 'ID','Delivery_person_ID'],inplace = True)

# %%
df.columns
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weatherconditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken(min)',
#        'delivery_time_mins', 'weather_clean', 'is_late', 'distance_km'],
#       dtype='object')

# %%
import seaborn as s

# %%
s.boxplot(x="Delivery_person_Age",
              y = 'delivery_time_mins', data= df)
# Out:
# <Axes: xlabel='Delivery_person_Age', ylabel='delivery_time_mins'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2878 entries, 0 to 2987
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Delivery_person_Age          2878 non-null   int64
#  1   Delivery_person_Ratings      2878 non-null   float64
#  2   Restaurant_latitude          2878 non-null   float64
#  3   Restaurant_longitude         2878 non-null   float64
#  4   Delivery_location_latitude   2878 non-null   float64
#  5   Delivery_location_longitude  2878 non-null   float64
#  6   Order_Date                   2878 non-null   object
#  7   Time_Orderd                  2878 non-null   object
#  8   Time_Order_picked            2878 non-null   object
#  9   Weatherconditions            2878 non-null   object
#  10  Road_traffic_density         2878 non-null   object
#  11  Vehicle_condition            2878 non-null   int64
#  12  Type_of_order                2878 non-null   object
#  13  Type_of_vehicle              2878 non-null   object
#  14  multiple_deliveries          2878 non-null   int64
#  15  Festival                     2878 non-null   object
#  16  City                         2878 non-null   object
#  17  Time_taken(min)              2878 non-null   object
#  18  delivery_time_mins           2878 non-null   int64
#  19  weather_clean                2878 non-null   object
#  20  is_late                      2878 non-null   int64
#  21  distance_km                  2878 non-null   float64
# dtypes: float64(6), int64(5), object(11)
# memory usage: 581.7+ KB
