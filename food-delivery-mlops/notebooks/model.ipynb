# %%
# libraries
import pandas as pd
import numpy as np

# %%
# loading the dataset
X_train = pd.read_csv("../data/processed/X_train.csv")

X_test = pd.read_csv("../data/processed/x_test.csv")

y_train = pd.read_csv("../data/processed/y_train.csv")

y_test = pd.read_csv("../data/processed/y_test.csv")

# %%
# models i gonna train
"""
1. Linear Regression
2. Ridge Regression
3. Lasso Regression
4. Elastic Net
5. Decision Tree Regressor
6. Random Forest Regressor
7. Extra Trees Regressor
8. Gradient Boosting Regressor
9. AdaBoost Regressor
10. XGBoost Regressor
11. CatBoost Regressor
12. KNN Regressor """
# Out:
# '\n1. Linear Regression\n2. Ridge Regression\n3. Lasso Regression\n4. Elastic Net\n5. Decision Tree Regressor\n6. Random Forest Regressor\n7. Extra Trees Regressor\n8. Gradient Boosting Regressor\n9. AdaBoost Regressor\n10. XGBoost Regressor\n11. CatBoost Regressor\n12. KNN Regressor '

# %%
# linear regression 


from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

lr = LinearRegression()

lr.fit(X_train,y_train)


y_pred = lr.predict(X_test)

# Evaluation
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("Linear Regression Results")
print("-" * 30)
print(f"MAE  : {mae:.4f}")
print(f"MSE  : {mse:.4f}")
print(f"RMSE : {rmse:.4f}")
print(f"R²   : {r2:.4f}")
# Out:
# Linear Regression Results
# ------------------------------
# MAE  : 4.5964
# MSE  : 32.9958
# RMSE : 5.7442
# R²   : 0.6162

# %%
# Decision Tree

from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Create model
dt = DecisionTreeRegressor(random_state=42)

# Train
dt.fit(X_train, y_train)

# Predict
y_pred = dt.predict(X_test)

# Metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("Decision Tree Results")
print("-" * 30)
print(f"MAE  : {mae:.4f}")
print(f"MSE  : {mse:.4f}")
print(f"RMSE : {rmse:.4f}")
print(f"R²   : {r2:.4f}")
# Out:
# Decision Tree Results
# ------------------------------
# MAE  : 4.3064
# MSE  : 32.8806
# RMSE : 5.7342
# R²   : 0.6176

# %%
# Random Forest Regressor

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Create model
rf = RandomForestRegressor(
    n_estimators=100,
    random_state=42,
    n_jobs=-1
)

# Train
rf.fit(X_train, y_train)

# Predict
y_pred = rf.predict(X_test)

# Metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("Random Forest Results")
print("-" * 30)
print(f"MAE  : {mae:.4f}")
print(f"MSE  : {mse:.4f}")
print(f"RMSE : {rmse:.4f}")
print(f"R²   : {r2:.4f}")
# Out:
# c:\ProgramData\anaconda3\envs\delivery_time\lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Random Forest Results
# ------------------------------
# MAE  : 3.4320
# MSE  : 18.8465
# RMSE : 4.3413
# R²   : 0.7808

# %%
import mlflow

mlflow.set_experiment("Delivery_Time_Prediction")

with mlflow.start_run(run_name="test_run"):
    mlflow.log_param("test_param", 123)
    mlflow.log_metric("test_metric", 0.95)

# %%
import mlflow

print("Tracking URI:", mlflow.get_tracking_uri())
# Out:
# Tracking URI: sqlite:///E:/Project/9.untitled%20project/food-delivery-mlops/notebooks/mlflow.db

# %%
for exp in mlflow.search_experiments():
    print(exp.experiment_id, exp.name)
# Out:
# 2 Delivery_Time_Prediction
# 1 Delivery_Time_prediction
# 0 Default

# %%
import mlflow

print("Current Experiment:")
print(mlflow.get_experiment_by_name("Delivery_Time_Prediction"))
# Out:
# Current Experiment:
# <Experiment: artifact_location='file:///e:/Project/9.untitled project/food-delivery-mlops/notebooks/mlruns/2', creation_time=1781113254020, effective_trace_archival_retention=None, experiment_id='2', last_update_time=1781113254020, lifecycle_stage='active', name='Delivery_Time_Prediction', tags={}, trace_location=None, workspace='default'>

# %%
with mlflow.start_run(run_name="test_run"):
    mlflow.log_param("model", "LinearRegression")
    mlflow.log_metric("mae", 10)
